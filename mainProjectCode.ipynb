# %%
import os
import time
import subprocess
import json
import cv2

# %%
import wolframalpha
import requests
import webbrowser
import wikipedia
import datetime

# %%
import speech_recognition as sr
import pyttsx3
from matplotlib import pyplot as plt

# %%
assistant_name = "HeeMeetsu"
user_name = "Merl"

# %%
print('Loading your personal assistant ' + assistant_name)
# Out:
# Loading your personal assistant HeeMeetsu

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice',voices[0].id)

# %%
def speak(text):
    print("\n" + text)
    engine.say(text)
    engine.runAndWait()

# %%
def wishMe():
    hour = datetime.datetime.now().hour
    if hour >= 0 and hour < 12:
        speak('Good Morning ' + user_name)
    elif hour >= 12 and hour < 16:
        speak('Good Afternoon ' + user_name)
    elif hour >=16 and hour <21:
        speak ('Good Evening ' + user_name)
    else:
        speak('Good night ' + + user_name)

# %%
def takeCommand():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("I am Listening...")
        audio = recognizer.listen(source)
        
        try:
            statement = recognizer.recognize_google(audio, language='en-in')
            print(f"user said : {statement}\n")
        except Exception as e:
            speak("Pardon me, can you please repeat?")
            return "None"
        return statement

# %%
def clickPicture():
    videoCaptureObject = cv2.VideoCapture(0)
    result = True
    while(result):
        ret,frame = videoCaptureObject.read()
        cv2.imwrite("MyPicture.jpg",frame)
        result = False
    videoCaptureObject.release()
    cv2.destroyAllWindows()
    speak(assistant_name + " clicked your picture :")
    img = cv2.imread('MyPicture.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(gray)
    plt.title('my picture')
    plt.show()

# %%
speak("Loading your personal assistant " + assistant_name)
wishMe()
# Out:
# Loading your personal assistant HeeMeetsu
# Good Afternoon Merl

# %%
if __name__ == '__main__' :
    while True:
        speak("How can I help you?")
        statement = takeCommand().lower()
        if statement == 0:
            continue
            
        if "good bye" in statement or "okay bye" in statement or "stop" in statement or "bye" in statement:
            speak(assistant_name + " will see you later. Good bye")
            break
            
        if "wikipedia" in statement:
            speak("Searching wikipedia...")
            statement = statement.replace("wikipedia"," ")
            results = wikipedia.summary(statement, sentences = 3)
            speak("According to wikipedia...")
            speak(results)
            
        elif "open youtube" in statement:
            speak("Opening Youtube..")
            webbrowser.open_new_tab("https://www.youtube.com")
            time.sleep(7)
            
        elif "open google" in statement:
            speak("Opening Google search..")
            webbrowser.open_new_tab("https://www.google.com")
            time.sleep(7)
            
        elif "open g mail" in statement:
            speak("Opening G mail..")
            webbrowser.open_new_tab("https://www.gmail.com")
            time.sleep(7)
            
        elif "weather" in statement:
            api_key = "886705b4c1182eb1c69f28eb8c520e20"
            base_url = "https://api.openweathermap.org/data/2.5/weather?"
            speak("Whats the city name?")
            city_name = takeCommand()
            complete_url = base_url + "q=" + city_name + "&appid=" + api_key
            response = requests.get(complete_url)
            json_data = response.json()
            if json_data["cod"] != "404" :
                #print(json_data)
                weather_data = json_data["main"]
                current_temperature =  weather_data["temp"]
                current_humidity =  weather_data["humidity"]
                x = json_data["weather"]
                weather_description = x[0]["description"]
                speak("The temperature in Kelvin is " + str(current_temperature) + 
                     "\nThe humidity in percentage is " + str(current_humidity) +
                     "\nWeather description is " + str(weather_description))
            else:
                speak("City not found")
                
        elif "time" in statement:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"The time is {strTime}")
            
        elif "who are you" in statement or "what can you do" in statement:
            speak("Hey, my name is " + assistant_name + ".\n" + 
                 "I can do tasks such as opening google, wikipedia and youtube.\n" +
                 "Ask me the time or weather or to take a picture of you.")
        
        elif "made you" in statement or "created you" in statement or "invented you" in statement:
            speak("I was built by " +  user_name)
            
        elif "open stack overflow" in statement:
            webbrowser.open_new_tab("https://stackoverflow.com/login")
            time.sleep(10)
        
        elif "news" in statement:
            news = webbrowser.open_new_tab("https://timesofindia.indiatimes.com/home/headlines")
            speak("Here are some headlines for the day.")
            time.sleep(10)
            
        elif "search" in statement:
            statement = statement.replace("search"," ")
            webbrowser.open_new_tab(statement)
            time.sleep(10)
            
        elif "ask" in statement or "answer me" in statement:
            speak("I can answer computational and geographical questions too.. Try me.\n" +
                 "What do you want to ask?")
            question = takeCommand()
            app_id = "R2K75H-7ELALHR35X"
            client = wolframalpha.Client(app_id)
            res = client.query(question)
            answer = next(res.results).text
            speak(answer)
            
        elif "log off" in statement or "sign out" in statement or "shut down" in statement:
            speak("Okay, Your PC will shut down in 10 seconds.\n" + 
                 "Make sure you save and have exited from all applications.\n" +
                 "That's a good bye from " + assistant_name + ".\n See you.")
            subprocess.call(["shutdown","/1"])
            
        elif "my picture" in statement or "my image" in statement or "camera" in statement or "photo" in statement:
            clickPicture()
            time.sleep(5)
            
        elif "instagram" in statement:
            speak("Please enter your instagram username")
            uname = input()
            webbrowser.open_new_tab("https://www.instagram.com/" + uname + "/")
            time.sleep(3)
        
    time.sleep(7)
# Out:
# How can I help you?
# I am Listening...
# user said : who created you
#
#
# I was built by Merl
#
# How can I help you?
# I am Listening...
# user said : what can you do
#
#
# Hey, my name is HeeMeetsu.
# I can do tasks such as opening google, wikipedia and youtube.
# Ask me the time or weather or to take a picture of you.
#
# How can I help you?
# I am Listening...
# user said : what's the time
#
#
# The time is 13:41:08
#
# How can I help you?
# I am Listening...
# user said : how is the weather
#
#
# Whats the city name?
# I am Listening...
# user said : Bangalore
#
#
# The temperature in Kelvin is 302.32
# The humidity in percentage is 55
# Weather description is scattered clouds
#
# How can I help you?
# I am Listening...
# user said : open Google
#
#
# Opening Google search..
#
# How can I help you?
# I am Listening...
# user said : open Gmail
#
#
# How can I help you?
# I am Listening...
# user said : according to Wikipedia what is a black hole
#
#
# Searching wikipedia...
#
# According to wikipedia...
#
# The Black Hole of Calcutta was a dungeon in Fort William, Calcutta measuring 4.30 × 5.50 ⁠metres (14 × 18 ⁠⁠feet), in which troops of Siraj ud-Daulah, the Nawab of Bengal, held British prisoners of war on the night of 20 June 1756. John Zephaniah Holwell, one of the British prisoners and an employee of the East India Company, said that, after the fall of Fort William, the surviving British soldiers, Indian sepoys, and Indian civilians were imprisoned overnight in conditions so cramped that many people died from suffocation and heat exhaustion, and that 123 of 146 prisoners of war imprisoned there died.  Modern historians believe that 64 prisoners were sent into the Hole, and that 43 died there.
#
# How can I help you?
# I am Listening...
# user said : what today's news
#
#
# Here are some headlines for the day.
#
# How can I help you?
# I am Listening...
# user said : the meaning of
#
#
# How can I help you?
# I am Listening...
# user said : open Instagram
#
#
# Please enter your instagram username
# merline.biju
#
# How can I help you?
# I am Listening...
# user said : open tap overflow
#
#
# How can I help you?
# I am Listening...
#
# Pardon me, can you please repeat?
#
# How can I help you?
# I am Listening...
# user said : click my picture
#
#
# HeeMeetsu clicked your picture :
# How can I help you?
# I am Listening...
# user said : what else can I ask you
#
#
# I can answer computational and geographical questions too.. Try me.
# What do you want to ask?
# I am Listening...
# user said : how large is India
#
#
# 3.287×10^6 km^2 (square kilometers) (world rank: 7th)
#
# How can I help you?
# I am Listening...
# user said : ok
#
#
# How can I help you?
# I am Listening...
# user said : bhai
#
#
# How can I help you?
# I am Listening...
# user said : goodbye
#
#
# HeeMeetsu will see you later. Good bye
